# %%
import json
import pandas as pd

# %% [markdown]
# ### Merge fb15k  with wn18rr:

# %%
relations_fb15k = json.loads(open(f'./fb15k237/relations.json').read())
relations_wn18  = json.loads(open(f'./wn18rr/relations.json').read())
relations_fb15k.update(relations_wn18)

# %%
# '/location/location/contains' -> '_has_part'
id_has_part = relations_fb15k.pop('/location/location/contains')
relations_fb15k['_has_part'] = id_has_part

# '/people/profession/specialization_of' -> '_hypernym'
id_hypernym = relations_fb15k.pop('/people/profession/specialization_of')
relations_fb15k['_hypernym'] = id_hypernym

#'/user/ktrueman/default_domain/international_organization/member_states' -> '_member_meronym'
id_member_meronym = relations_fb15k.pop('/user/ktrueman/default_domain/international_organization/member_states')
relations_fb15k['_member_meronym'] = id_member_meronym

# %%
id_has_part
# Out:
# 15

# %%
relations_fb15k = {key: id for id, (key, _) in enumerate(relations_fb15k.items())}

# %%
mapping_new_relation = {
    id_has_part: relations_fb15k['_has_part'],
    id_hypernym: relations_fb15k['_hypernym'],
    id_member_meronym: relations_fb15k['_member_meronym'],
    
}

# %%
with open('./kdmkr_fb15k237/relations.json', 'w') as output_file:
    json.dump(relations_fb15k, output_file, indent=4)

# %%
entities_wn18 = json.loads(open(f'./wn18rr/entities.json').read())

entities_wn18 = pd.DataFrame(
    pd.Series(entities_wn18)
).reset_index().drop(0, axis = 'columns').rename(columns={'index': 'entity'})

entities_wn18['tag'] = entities_wn18['entity'].str[-5:]

entities_wn18['entity'] = entities_wn18['entity'].str.split('.').str[0]

entities_wn18 = entities_wn18.drop_duplicates('entity')

# %%
train = pd.read_csv('./fb15k237/train.csv', header = None)
valid = pd.read_csv('./fb15k237/valid.csv', header = None)
test  = pd.read_csv('./fb15k237/test.csv', header  = None)

train.columns = ['head', 'relation', 'tail']
valid.columns = ['head', 'relation', 'tail']
test.columns  = ['head', 'relation', 'tail']

# %%
train
# Out:
#         head  relation   tail
# 0          0         0  13624
# 1          1         1   3865
# 2          2         2  11613
# 3          3         3   5093
# 4          4         4   1243
# ...      ...       ...    ...
# 272110  5476        11  13625
# 272111  1483        20   1445
# 272112  4820       170  10221
# 272113  2386        30   5370
# 272114  8958        38   8818
#
# [272115 rows x 3 columns]

# %%
def map_new_relation(r, mapping_new_relation):
    if r in mapping_new_relation:
        return mapping_new_relation[r]
    else:
        return r
    
train['relation'] = train['relation'].apply(lambda r: map_new_relation(r, mapping_new_relation))


valid['relation'] = valid['relation'].apply(lambda r: map_new_relation(r, mapping_new_relation))

test['relation'] = test['relation'].apply(lambda r: map_new_relation(r, mapping_new_relation))

# %%
entities_fb15k = json.loads(open(f'./fb15k237/entities.json').read())
entities_fb15k = {value: key for key, value in entities_fb15k.items()}

# %%
train['head'] = train['head'].apply(lambda x: entities_fb15k[x])
train['tail'] = train['tail'].apply(lambda x: entities_fb15k[x])

valid['head'] = valid['head'].apply(lambda x: entities_fb15k[x])
valid['tail'] = valid['tail'].apply(lambda x: entities_fb15k[x])

test['head'] = test['head'].apply(lambda x: entities_fb15k[x])
test['tail'] = test['tail'].apply(lambda x: entities_fb15k[x])

# %%
train.head()
# Out:
#                                            head  relation                tail
# 0                            dominican_republic         0            republic
# 1                  mighty_morphin_power_rangers         1          wendee_lee
# 2                                    drama_film         2  american_history_x
# 3                            michelle_rodriguez         3      naveen_andrews
# 4  australia_national_association_football_team         4          midfielder

# %%
def update_entity_name_fb15k(on, df):

    df = pd.merge(
        left     = df,
        right    = entities_wn18,
        how      = 'left',
        left_on  = on,
        right_on = 'entity'
    )

    df['tag'] = df['tag'].fillna('')

    df[on] = df[on] + df['tag']

    df.drop(['entity', 'tag'], axis='columns', inplace=True)
    
    return df

# %%
train = update_entity_name_fb15k(on='head', df=train)
train = update_entity_name_fb15k(on='tail', df=train)

valid = update_entity_name_fb15k(on='head', df=valid)
valid = update_entity_name_fb15k(on='tail', df=valid)

test = update_entity_name_fb15k(on='head', df=test)
test = update_entity_name_fb15k(on='tail', df=test)

# %%
df = pd.concat([train, valid, test])

# %%
entities = pd.concat(
    [
        pd.DataFrame(df['head']).rename(columns={'head':'entity'}), 
        pd.DataFrame(df['tail']).rename(columns={'tail':'entity'}), 
    ], 
    sort=False
)

# %%
entities = entities.drop_duplicates().reset_index(drop=True)

# %%
entities = entities.to_dict()['entity']
entities = {value: key for key, value in entities.items()}

# %%
with open('./kdmkr_fb15k237/entities.json', 'w') as output_file:
    json.dump(entities, output_file, indent=4)

# %%
train['head'] = train['head'].apply(lambda x: entities[x])
train['tail'] = train['tail'].apply(lambda x: entities[x])

valid['head'] = valid['head'].apply(lambda x: entities[x])
valid['tail'] = valid['tail'].apply(lambda x: entities[x])

test['head'] = test['head'].apply(lambda x: entities[x])
test['tail'] = test['tail'].apply(lambda x: entities[x])

# %%
train.head()
# Out:
#    head  relation   tail
# 0     0         0  13624
# 1     1         1   3865
# 2     2         2  11613
# 3     3         3   5093
# 4     4         4   1243

# %%
valid.head()
# Out:
#    head  relation   tail
# 0  4349        31   2741
# 1  9339       154  13672
# 2  6274        85    950
# 3  7226        47   2160
# 4  1404        13    596

# %%
test.head()
# Out:
#    head  relation   tail
# 0  4798       148  10648
# 1   838        92  12858
# 2  4578        13    352
# 3  1164       240  14139
# 4  1164       240  12385

# %%
train.to_csv('./kdmkr_fb15k237/train.csv', header=None, index=False)
valid.to_csv('./kdmkr_fb15k237/valid.csv', header=None, index=False)
test.to_csv('./kdmkr_fb15k237/test.csv', header=None, index=False)

# %% [markdown]
# ## Merge wn18rr with fb15k237:

# %%
relations_fb15k = json.loads(open(f'./fb15k237/relations.json').read())
relations_wn18  = json.loads(open(f'./wn18rr/relations.json').read())
relations_wn18.update(relations_fb15k)
relations_wn18 = {key: id for id, (key, _) in enumerate(relations_wn18.items())}

# %%
with open('./kdmkr_wn18rr/relations.json', 'w') as output_file:
    json.dump(relations_wn18, output_file, indent=4)

# %%
train = pd.read_csv('./wn18rr/train.csv', header=None)
valid = pd.read_csv('./wn18rr/valid.csv', header=None)
test  = pd.read_csv('./wn18rr/test.csv', header=None)

# %%
train.to_csv('./kdmkr_wn18rr/train.csv', index=False, header=None)
valid.to_csv('./kdmkr_wn18rr/valid.csv', index=False, header=None)
test.to_csv('./kdmkr_wn18rr/test.csv', index=False, header=None)

# %% [markdown]
# # Strategie 2

# %%
# 237 entities for fb15k237
# 11  entities for wn18rr

# %%
inverse_relations_fb15k = {id: key for key, id in relations_fb15k.items()}
df_fb_15k = df.copy(deep=True)
df_fb_15k['relation'] = df_fb_15k['relation'].apply(lambda r: inverse_relations_fb15k[r])
df_fb_15k.columns = ['head', 'relation_fb15K', 'tail']
df_fb_15k.head()
# Out:
#                                            head  \
# 0                       dominican_republic.n.01
# 1                  mighty_morphin_power_rangers
# 2                                    drama_film
# 3                            michelle_rodriguez
# 4  australia_national_association_football_team
#
#                                       relation_fb15K                tail
# 0               /location/country/form_of_government            republic
# 1  /tv/tv_program/regular_cast./tv/regular_tv_app...          wendee_lee
# 2                 /media_common/netflix_genre/titles  american_history_x
# 3  /award/award_winner/awards_won./award/award_ho...      naveen_andrews
# 4  /soccer/football_team/current_roster./sports/s...          midfielder

# %%
inversed_relations_wn18 = {id: key for key, id in relations_wn18.items()}
entities_wn_18 = json.loads(open(f'./wn18rr/entities.json').read())
inversed_entities_wn_18 = {id: key for key, id in entities_wn_18.items()}
wn18rr_df = pd.concat([train, valid, test], sort = False)
wn18rr_df.columns = ['head', 'relation_wn18', 'tail']
wn18rr_df['relation_wn18'] = wn18rr_df['relation_wn18'].apply(lambda r: inversed_relations_wn18[r])
wn18rr_df['head'] = wn18rr_df['head'].apply(lambda h: inversed_entities_wn_18[h])
wn18rr_df['tail'] = wn18rr_df['tail'].apply(lambda t: inversed_entities_wn_18[t])

# %%
wn18rr_df.head()
# Out:
#                head                 relation_wn18                tail
# 0  land_reform.n.01                     _hypernym         reform.n.01
# 1        cover.v.01  _derivationally_related_form       covering.n.02
# 2       botany.n.02  _derivationally_related_form       botanize.v.01
# 3        kamet.n.01            _instance_hypernym  mountain_peak.n.01
# 4     question.n.01  _derivationally_related_form            ask.v.01

# %%
common = pd.merge(
    left = df_fb_15k,
    right = wn18rr_df,
    on = ['head', 'tail'],
    how = 'left'
)

# %%
common = common[common['relation_wn18'].notnull()]

# %%
common_entities = pd.concat([
    common['head'].rename(columns={'head': 'entity'}),
    common['tail'].rename(columns={'tail': 'entity'}),
]).drop_duplicates()

# %%
common
# Out:
#                                            head  \
# 104                                algeria.n.01
# 181                                 europe.n.01
# 514                                 kyushu.n.01
# 583                                 brazil.n.01
# 638                              lithuania.n.01
# ...                                         ...
# 306485                               czech.a.01
# 306595  north_atlantic_treaty_organization.n.01
# 307514                   iberian_peninsula.n.01
# 308861                               texas.n.01
# 309891                             arizona.n.01
#
#                                            relation_fb15K  \
# 104                             /location/country/capital
# 181           /base/locations/continents/countries_within
# 514                           /location/location/contains
# 583                           /location/location/contains
# 638                           /location/location/contains
# ...                                                   ...
# 306485       /language/human_language/countries_spoken_in
# 306595  /user/ktrueman/default_domain/international_or...
# 307514              /location/location/partially_contains
# 308861                        /location/location/contains
# 309891                        /location/location/contains
#
#                        tail                 relation_wn18
# 104            algiers.n.01                     _has_part
# 181             poland.n.01                     _has_part
# 514           nagasaki.n.01                     _has_part
# 583     rio_de_janeiro.n.01                     _has_part
# 638            vilnius.n.01                     _has_part
# ...                     ...                           ...
# 306485  czechoslovakia.n.01  _derivationally_related_form
# 306595         denmark.n.01               _member_meronym
# 307514           spain.n.01                     _has_part
# 308861          laredo.n.01                     _has_part
# 309891            mesa.n.02                     _has_part
#
# [735 rows x 4 columns]

# %%
relation = '/user/ktrueman/default_domain/international_organization/member_states'


common[common['relation_fb15K'] == relation]
# Out:
#                                            head  \
# 29876   north_atlantic_treaty_organization.n.01
# 54371   north_atlantic_treaty_organization.n.01
# 94562   north_atlantic_treaty_organization.n.01
# 102208  north_atlantic_treaty_organization.n.01
# 123101  north_atlantic_treaty_organization.n.01
# 128759  north_atlantic_treaty_organization.n.01
# 180403  north_atlantic_treaty_organization.n.01
# 200220  north_atlantic_treaty_organization.n.01
# 219860  north_atlantic_treaty_organization.n.01
# 273146  north_atlantic_treaty_organization.n.01
# 279711  north_atlantic_treaty_organization.n.01
# 284304  north_atlantic_treaty_organization.n.01
# 294382  north_atlantic_treaty_organization.n.01
# 306595  north_atlantic_treaty_organization.n.01
#
#                                            relation_fb15K  \
# 29876   /user/ktrueman/default_domain/international_or...
# 54371   /user/ktrueman/default_domain/international_or...
# 94562   /user/ktrueman/default_domain/international_or...
# 102208  /user/ktrueman/default_domain/international_or...
# 123101  /user/ktrueman/default_domain/international_or...
# 128759  /user/ktrueman/default_domain/international_or...
# 180403  /user/ktrueman/default_domain/international_or...
# 200220  /user/ktrueman/default_domain/international_or...
# 219860  /user/ktrueman/default_domain/international_or...
# 273146  /user/ktrueman/default_domain/international_or...
# 279711  /user/ktrueman/default_domain/international_or...
# 284304  /user/ktrueman/default_domain/international_or...
# 294382  /user/ktrueman/default_domain/international_or...
# 306595  /user/ktrueman/default_domain/international_or...
#
#                        tail    relation_wn18
# 29876   united_kingdom.n.01  _member_meronym
# 54371      netherlands.n.01  _member_meronym
# 94562           france.n.01  _member_meronym
# 102208          canada.n.01  _member_meronym
# 123101         belgium.n.01  _member_meronym
# 128759          norway.n.01  _member_meronym
# 180403           italy.n.01  _member_meronym
# 200220        portugal.n.01  _member_meronym
# 219860        bulgaria.n.01  _member_meronym
# 273146          turkey.n.02  _member_meronym
# 279711           spain.n.01  _member_meronym
# 284304      luxembourg.n.02  _member_meronym
# 294382          greece.n.01  _member_meronym
# 306595         denmark.n.01  _member_meronym

# %%
pd.DataFrame(common_entities.reset_index(drop=True), columns=['entity'])
# Out:
#                   entity
# 0           algeria.n.01
# 1            europe.n.01
# 2            kyushu.n.01
# 3            brazil.n.01
# 4         lithuania.n.01
# ..                   ...
# 633  virginia_beach.n.01
# 634    cedar_rapids.n.01
# 635  czechoslovakia.n.01
# 636          laredo.n.01
# 637            mesa.n.02
#
# [638 rows x 1 columns]

# %%
common_statistics = common[
    ['relation_wn18', 'relation_fb15K', 'head']
      ].groupby(
    ['relation_fb15K', 'relation_wn18']
).count()


common_statistics.columns = ['triplet_with_common_head_tail']

common_statistics.sort_values(by = ['triplet_with_common_head_tail', 'relation_fb15K'], ascending = False)
# Out:
#                                                                                  triplet_with_common_head_tail
# relation_fb15K                                     relation_wn18
# /location/location/contains                        _has_part                                               464
# /base/locations/continents/countries_within        _has_part                                                71
# /location/country/capital                          _has_part                                                37
# /location/location/partially_contains              _has_part                                                27
# /base/aareas/schema/administrative_area/capital    _has_part                                                23
# /people/profession/specialization_of               _hypernym                                                17
# /user/ktrueman/default_domain/international_org... _member_meronym                                          14
# /location/country/second_level_divisions           _has_part                                                13
# /location/location/contains                        _member_of_domain_region                                 11
# /location/country/official_language                _member_meronym                                           6
# /music/performance_role/track_performances./mus... _hypernym                                                 5
# /music/performance_role/regular_performances./m... _hypernym                                                 5
# /location/country/official_language                _member_of_domain_region                                  5
# /language/human_language/countries_spoken_in       _derivationally_related_form                              5
# /music/performance_role/guest_performances./mus... _hypernym                                                 4
# /music/instrument/family                           _hypernym                                                 4
# /education/field_of_study/students_majoring./ed... _hypernym                                                 4
# /location/statistical_region/religions./locatio... _member_of_domain_region                                  3
# /people/profession/specialization_of               _derivationally_related_form                              2
# /people/person/profession                          _instance_hypernym                                        2
# /location/location/adjoin_s./location/adjoining... _has_part                                                 2
# /location/country/official_language                _derivationally_related_form                              2
# /film/film_subject/films                           _has_part                                                 2
# /dataworld/gardening_hint/split_to                 _derivationally_related_form                              2
# /music/genre/parent_genre                          _hypernym                                                 1
# /media_common/netflix_genre/titles                 _member_of_domain_region                                  1
# /location/country/second_level_divisions           _member_of_domain_region                                  1
# /film/film_subject/films                           _member_of_domain_region                                  1
# /base/locations/continents/countries_within        _member_of_domain_region                                  1

# %%
# _has_part -> /location/location/contains

# %%
total_relation = pd.DataFrame(df_fb_15k['relation_fb15K'].value_counts())

# %%
total_relation.reset_index()[total_relation.reset_index()['index'] == '/location/location/contains']
# Out:
#                           index  relation_fb15K
# 12  /location/location/contains            5834

# %%
/location/location/contains -> has part
# Out:
#   File "<ipython-input-68-ce51c3502640>", line 1
#     location/location/contains(->, has, part)
#                                 ^
# SyntaxError: invalid syntax

# %%
common_head = pd.merge(
    left = df_fb_15k,
    right = wn18rr_df.rename(columns={'tail': 'tail_wn18_rr'}),
    on = ['head'],
    how = 'left'
)

common_head = common_head[common_head['relation_wn18'].notnull()]

common_head.drop(['relation_wn18', 'tail_wn18_rr'], axis = 'columns', inplace=True)

common_head = common_head.drop_duplicates()

# %%
common_head.head()
# Out:
#                        head  \
# 0   dominican_republic.n.01
# 9          harpsichord.n.01
# 52      prime_minister.n.01
# 60             cabaret.n.01
# 65             beijing.n.01
#
#                                        relation_fb15K  \
# 0                /location/country/form_of_government
# 9   /music/performance_role/regular_performances./...
# 52  /government/government_office_category/officeh...
# 60  /award/award_winning_work/awards_won./award/aw...
# 65     /common/topic/webpage./common/webpage/category
#
#                          tail
# 0                    republic
# 9                 violin.n.01
# 52              dominica.n.01
# 60  bafta_award_for_best_film
# 65                 /m/08mbj5d

# %%
common_tail = pd.merge(
    left = common_head,
    right = wn18rr_df.rename(columns={'head': 'head_wn18_rr'}),
    on = ['tail'],
    how = 'left'
)


common_tail = common_tail[common_tail['relation_wn18'].notnull()]

common_tail.drop(['relation_wn18', 'head_wn18_rr'], axis = 'columns', inplace=True)

common_tail = common_tail.drop_duplicates()

# %%
common_tail['relation_fb15K'].value_counts().head(15)
# Out:
# /film/film/release_date_s./film/film_regional_release_date/film_release_region                                      1026
# /location/location/contains                                                                                          865
# /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country                                       817
# /location/location/adjoin_s./location/adjoining_relationship/adjoins                                                 734
# /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month                                  456
# /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office     442
# /military/military_combatant/military_conflicts./military/military_combatant_group/combatants                        408
# /music/performance_role/track_performances./music/track_contribution/role                                            344
# /location/statistical_region/religions./location/religion_percentage/religion                                        325
# /music/performance_role/regular_performances./music/group_membership/role                                            313
# /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony                                269
# /language/human_language/countries_spoken_in                                                                         249
# /base/aareas/schema/administrative_area/administrative_parent                                                        246
# /film/film/language                                                                                                  208
# /education/field_of_study/students_majoring./education/education/major_field_of_study                                201
# Name: relation_fb15K, dtype: int64

# %%
relation = '/people/profession/specialization_of'

common_tail[common_tail['relation_fb15K'] == relation]
# Out:
#                           head                        relation_fb15K  \
# 360                bishop.n.01  /people/profession/specialization_of
# 573            astronomer.n.01  /people/profession/specialization_of
# 3778           supermodel.n.01  /people/profession/specialization_of
# 6672              drummer.n.01  /people/profession/specialization_of
# 7075               acting.n.01  /people/profession/specialization_of
# 7512          advertising.n.02  /people/profession/specialization_of
# 8759             organist.n.01  /people/profession/specialization_of
# 10190        spokesperson.n.01  /people/profession/specialization_of
# 10348             psychic.n.01  /people/profession/specialization_of
# 10631             fiction.n.01  /people/profession/specialization_of
# 13761             science.n.01  /people/profession/specialization_of
# 13888           surveying.n.01  /people/profession/specialization_of
# 13947    environmentalist.n.01  /people/profession/specialization_of
# 14169               judge.v.05  /people/profession/specialization_of
# 15361             monarch.n.02  /people/profession/specialization_of
# 15764          astrologer.n.01  /people/profession/specialization_of
# 16288           solicitor.n.01  /people/profession/specialization_of
# 16782           geologist.n.01  /people/profession/specialization_of
# 16882        photographer.n.01  /people/profession/specialization_of
# 16961            merchant.n.01  /people/profession/specialization_of
# 20478       mathematician.n.01  /people/profession/specialization_of
# 20965      harpsichordist.n.01  /people/profession/specialization_of
# 21366           physicist.n.01  /people/profession/specialization_of
# 22994               ninja.n.02  /people/profession/specialization_of
# 24345      civil_engineer.n.01  /people/profession/specialization_of
# 24604          legislator.n.01  /people/profession/specialization_of
# 27378         photography.n.03  /people/profession/specialization_of
# 28466                poet.n.01  /people/profession/specialization_of
# 31052          conducting.n.02  /people/profession/specialization_of
# 32467          biochemist.n.01  /people/profession/specialization_of
# 36678  computer_scientist.n.01  /people/profession/specialization_of
# 39751           barrister.n.01  /people/profession/specialization_of
# 40735             chemist.n.01  /people/profession/specialization_of
# 41823          cartoonist.n.01  /people/profession/specialization_of
# 41866           guitarist.n.01  /people/profession/specialization_of
# 44239        statistician.n.02  /people/profession/specialization_of
# 45709           biologist.n.01  /people/profession/specialization_of
# 46480             pianist.n.01  /people/profession/specialization_of
# 46976          journalist.n.01  /people/profession/specialization_of
# 48457          songwriter.n.01  /people/profession/specialization_of
# 48891              author.v.01  /people/profession/specialization_of
# 50096         illustrator.n.01  /people/profession/specialization_of
# 51042         engineering.n.02  /people/profession/specialization_of
# 51820            musician.n.02  /people/profession/specialization_of
# 53991            composer.n.01  /people/profession/specialization_of
# 54294    environmentalist.n.01  /people/profession/specialization_of
# 54707          art_critic.n.01  /people/profession/specialization_of
# 55358            diplomat.n.01  /people/profession/specialization_of
# 57775          accountant.n.01  /people/profession/specialization_of
# 60085          programmer.n.01  /people/profession/specialization_of
# 60149            lyricist.n.01  /people/profession/specialization_of
#
#                       tail
# 360            priest.n.02
# 573         scientist.n.01
# 3778            model.v.06
# 6672         musician.n.02
# 7075            actor.n.01
# 7512   businessperson.n.01
# 8759         musician.n.02
# 10190           actor.n.01
# 10348         prophet.n.01
# 10631          writer.n.01
# 13761       scientist.n.01
# 13888        engineer.v.01
# 13947       scientist.n.01
# 14169        official.n.01
# 15361      politician.n.02
# 15764         prophet.n.01
# 16288          lawyer.n.01
# 16782       scientist.n.01
# 16882          artist.n.01
# 16961  businessperson.n.01
# 20478       scientist.n.01
# 20965        musician.n.02
# 21366       scientist.n.01
# 22994         soldier.n.01
# 24345        engineer.v.01
# 24604      politician.n.02
# 27378          artist.n.01
# 28466          writer.n.01
# 31052        musician.n.02
# 32467         chemist.n.01
# 36678       scientist.n.01
# 39751          lawyer.n.01
# 40735       scientist.n.01
# 41823          artist.n.01
# 41866        musician.n.02
# 44239   mathematician.n.01
# 45709       scientist.n.01
# 46480        musician.n.02
# 46976          writer.n.01
# 48457        musician.n.02
# 48891          writer.n.01
# 50096          artist.n.01
# 51042        engineer.v.01
# 51820          artist.n.01
# 53991        musician.n.02
# 54294      politician.n.02
# 54707          critic.n.03
# 55358        official.n.01
# 57775   mathematician.n.01
# 60085        engineer.v.01
# 60149          writer.n.01

# %%
head = 'history.n.01'
wn18rr_df[wn18rr_df['relation_wn18'] == '_member_meronym']
# Out:
#                       head    relation_wn18               tail
# 15        primulaceae.n.01  _member_meronym         glaux.n.01
# 16         proteaceae.n.01  _member_meronym  bartle_frere.n.01
# 30             taiwan.n.01  _member_meronym     taiwanese.n.01
# 38              carya.n.01  _member_meronym         pecan.n.02
# 91    hydrophyllaceae.n.01  _member_meronym  hydrophyllum.n.01
# ...                    ...              ...                ...
# 3022          encelia.n.01  _member_meronym   brittlebush.n.01
# 3037    cypriniformes.n.01  _member_meronym  catostomidae.n.01
# 3062        manteodea.n.01  _member_meronym      mantidae.n.01
# 3094      geraniaceae.n.01  _member_meronym      geranium.n.01
# 3129        trematoda.n.01  _member_meronym   fasciolidae.n.01
#
# [7928 rows x 3 columns]

# %%
df_fb_15k[df_fb_15k['relation_fb15K'] == '/user/ktrueman/default_domain/international_organization/member_states']
# Out:
#                                                     head  \
# 1245                                            /m/02jxk
# 8151   organisation_for_economic_co-operation_and_dev...
# 8807                       world_trade_organization.n.01
# 9234                       world_trade_organization.n.01
# 11538                      world_trade_organization.n.01
# ...                                                  ...
# 17812                      world_trade_organization.n.01
# 18495                      world_trade_organization.n.01
# 19086                                           /m/02jxk
# 19144                      world_trade_organization.n.01
# 20442                      world_trade_organization.n.01
#
#                                           relation_fb15K  \
# 1245   /user/ktrueman/default_domain/international_or...
# 8151   /user/ktrueman/default_domain/international_or...
# 8807   /user/ktrueman/default_domain/international_or...
# 9234   /user/ktrueman/default_domain/international_or...
# 11538  /user/ktrueman/default_domain/international_or...
# ...                                                  ...
# 17812  /user/ktrueman/default_domain/international_or...
# 18495  /user/ktrueman/default_domain/international_or...
# 19086  /user/ktrueman/default_domain/international_or...
# 19144  /user/ktrueman/default_domain/international_or...
# 20442  /user/ktrueman/default_domain/international_or...
#
#                                 tail
# 1245                    germany.n.01
# 8151        united_states_of_america
# 8807                       chad.n.04
# 9234   central_african_republic.n.01
# 11538                   hungary.n.01
# ...                              ...
# 17812                   morocco.n.01
# 18495                  barbados.n.02
# 19086                     italy.n.01
# 19144                    brunei.n.01
# 20442                  slovenia.n.01
#
# [218 rows x 3 columns]

# %%
df_fb_15k[df_fb_15k['relation_fb15K'] == '/people/profession/specialization_of']
# Out:
#                         head                        relation_fb15K  \
# 1468             bishop.n.01  /people/profession/specialization_of
# 2711         astronomer.n.01  /people/profession/specialization_of
# 5000      research_associate  /people/profession/specialization_of
# 5221           preacher.n.01  /people/profession/specialization_of
# 15179             rabbi.n.01  /people/profession/specialization_of
# ...                      ...                                   ...
# 16650          lyricist.n.01  /people/profession/specialization_of
# 16860  aerospace_engineering  /people/profession/specialization_of
# 17721        bandleader.n.01  /people/profession/specialization_of
# 18615           art_director  /people/profession/specialization_of
# 19114             coach.n.02  /people/profession/specialization_of
#
#                     tail
# 1468         priest.n.02
# 2711      scientist.n.01
# 5000   architecture.n.03
# 5221         clergy.n.01
# 15179        clergy.n.01
# ...                  ...
# 16650        writer.n.01
# 16860      engineer.v.01
# 17721     music_director
# 18615        artist.n.01
# 19114    management.n.02
#
# [125 rows x 3 columns]

# %%
# Has part -> /location/location/contains

# %%
import pandas as pd

# %%
file = 'test'

# %%
path = '/Users/home/Documents/github/datasets_knowledge_embedding/WN18RR/text'

# %%
dataset = pd.read_csv(f'{path}/{file}.txt', sep = '\t', header = None)

# %%
dataset.to_csv(f'/Users/home/Documents/github/mkb/mkb/datasets/wn18rr_text/{file}.csv', sep = '|', index = False, header = None)

# %%
dataset
# Out:
#                         0                             1                     2
# 0         trade_name.n.01       _member_of_domain_usage      metharbital.n.01
# 1               call.v.03                   _verb_group             call.v.09
# 2     united_kingdom.n.01      _member_of_domain_region            facer.n.01
# 3          blattodea.n.01               _member_meronym        cockroach.n.01
# 4     rickettsiaceae.n.01                     _hypernym  bacteria_family.n.01
# ...                   ...                           ...                   ...
# 3129       trematoda.n.01               _member_meronym      fasciolidae.n.01
# 3130          savior.n.02  _derivationally_related_form          deliver.v.08
# 3131        transmit.v.04  _derivationally_related_form   channelization.n.01
# 3132   grocery_store.n.01                     _has_part            shelf.n.01
# 3133   piciform_bird.n.01                     _hypernym             bird.n.01
#
# [3134 rows x 3 columns]

# %%
data =

# %%
# Out:
# [('trade_name.n.01', '_member_of_domain_usage', 'metharbital.n.01'),
#  ('call.v.03', '_verb_group', 'call.v.09'),
#  ('united_kingdom.n.01', '_member_of_domain_region', 'facer.n.01'),
#  ('blattodea.n.01', '_member_meronym', 'cockroach.n.01'),
#  ('rickettsiaceae.n.01', '_hypernym', 'bacteria_family.n.01'),
#  ('entoprocta.n.01', '_hypernym', 'phylum.n.02'),
#  ('position.n.01', '_hypernym', 'point.n.02'),
#  ('drill.n.01', '_has_part', 'chuck.n.03'),
#  ('breadfruit.n.01', '_hypernym', 'fruit_tree.n.01'),
#  ('rest.v.02', '_derivationally_related_form', 'breath.n.03'),
#  ('transformation.n.01', '_derivationally_related_form', 'shift.v.05'),
#  ('sympathizer.n.01', '_hypernym', 'communicator.n.01'),
#  ('ration.n.02', '_derivationally_related_form', 'ration.v.01'),
#  ('transfix.v.02', '_hypernym', 'pierce.v.04'),
#  ('chromosome.n.01', '_has_part', 'chromatin.n.01'),
#  ('surface.n.02', '_hypernym', 'boundary.n.01'),
#  ('accentuation.n.01', '_hypernym', 'stress.n.01'),
# ...
